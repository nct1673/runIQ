# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://runiq:runiq@localhost:5432/runiq")
df = pd.read_sql("SELECT * FROM activities_raw", engine)
